# %% [markdown]
# ### Goal

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os, sys
import pandas as pd
import numpy as np
import math

import matplotlib.pyplot as plt

# %%
import os
import shutil

def remove_subfolders_with_txt(directory):
    # Walk through all directories
    for root, dirs, files in os.walk(directory, topdown=False):
        # Check if there are any .txt files in current directory
        has_txt = any(file.endswith('.txt') for file in files)
        
        # If .txt files exist, remove all subdirectories at this level
        if has_txt:
            for dir_name in dirs:
                dir_path = os.path.join(root, dir_name)
                if os.path.exists(dir_path):  # Check if path still exists
                    print(f"Removing directory: {dir_path}")
                    #shutil.rmtree(dir_path)

# Example usage
directory_path = "/Users/michaelmoret/Library/CloudStorage/GoogleDrive-michael@externa.bio/.shortcut-targets-by-id/1BdUNsBjDh5Gee_76jCiKB1C_CwG0ercP/Pulling data/"
remove_subfolders_with_txt(directory_path)
# Out:
# Removing directory: /Users/michaelmoret/Library/CloudStorage/GoogleDrive-michael@externa.bio/.shortcut-targets-by-id/1BdUNsBjDh5Gee_76jCiKB1C_CwG0ercP/Pulling data/25-01-03/single/20250103$ IHNY 20mmmin$33%phosctrl $33% WAX-7 0.04 $33% WAX-7 0.08$single
# Removing directory: /Users/michaelmoret/Library/CloudStorage/GoogleDrive-michael@externa.bio/.shortcut-targets-by-id/1BdUNsBjDh5Gee_76jCiKB1C_CwG0ercP/Pulling data/25-01-03/single/20250103$ IHNY 20mmmin$33%phosctrl $33% WAX-5 0.04 $33% WAX-5 0.08$single
# Removing directory: /Users/michaelmoret/Library/CloudStorage/GoogleDrive-michael@externa.bio/.shortcut-targets-by-id/1BdUNsBjDh5Gee_76jCiKB1C_CwG0ercP/Pulling data/25-01-03/triple/20250103$ IHNY 20mmmin$33%phosctrl $33% WAX-7 0.04 $33% WAX-7 0.08$triple
# Removing directory: /Users/michaelmoret/Library/CloudStorage/GoogleDrive-michael@externa.bio/.shortcut-targets-by-id/1BdUNsBjDh5Gee_76jCiKB1C_CwG0ercP/Pulling data/25-01-03/triple/copy
# ...
